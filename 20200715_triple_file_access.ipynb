# %%
import os
import numpy as np
import pickle as pk
from matplotlib import pyplot as plt

# %% [markdown]
# BEFORE RUNNING, replace `[PATH]` in the following cell AND in `./C3POa/config.txt` with the full path to the `cas9-random-access` cloned repo.

# %%
date = "20200715"
input_dir = "/[PATH]/cas9-random-access/%s_basecalled_reads" % date # absolute path of directory containing basecalled reads in fastq format
output_dir = "/[PATH]/cas9-random-access/20200715_results" # absolute path of output directory
nuc_mat = "/[PATH]/cas9-random-access/C3POa/NUC.4.4.mat"
splint_seq = "splint_all.fasta"
config = "C3POa/config.txt"

# %%
reads_basecalled = 0
for x in os.listdir(input_dir):
    fastq = open(os.path.join(input_dir, x), 'r')
    for line in fastq:
        if line.strip() == "+":
            reads_basecalled += 1
    fastq.close()
print("Total Reads Passed Basecalling:", reads_basecalled)
# Out:
# Total Reads Passed Basecalling: 163298

# %% [markdown]
# # Preprocessing
# Demultiplex reads based on their file addresses.

# %%
pre_dir = os.path.join(output_dir, "preprocessing") # store demultiplexed reads in this directory

# %%
q_score = 9 
pre_length_cutoff = 100

# %%
for fastq in os.listdir(input_dir):
    print(fastq)
    fastq = os.path.join(input_dir, fastq)
    preprocess_cmd = "C3POa/C3POa_preprocessing.py -i %s -o %s -q %d -l %d -s %s -c %s" % (fastq, pre_dir, q_score, pre_length_cutoff, splint_seq, config)
    # !python3 {preprocess_cmd}
    print()
# Out:
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_0_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2984838 bases in 588 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_0_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3736114 bases in 749 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_0_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3512866 bases in 707 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_0_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3531496 bases in 692 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_1_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 4059830 bases in 844 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_1_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2623775 bases in 626 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_1_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2792504 bases in 575 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_1_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2882681 bases in 637 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_2_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2540700 bases in 553 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_2_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3252253 bases in 696 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_2_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2379048 bases in 493 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_2_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3180382 bases in 662 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_3_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3290632 bases in 651 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_3_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2683382 bases in 550 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_3_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2816462 bases in 534 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_3_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3403521 bases in 701 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_4_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3972825 bases in 816 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_4_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2793363 bases in 543 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_4_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2096825 bases in 417 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_4_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3324920 bases in 648 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_5_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3070441 bases in 614 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_5_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3229009 bases in 620 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_5_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3731209 bases in 778 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_5_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2328130 bases in 425 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_6_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3767278 bases in 743 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_6_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3507806 bases in 650 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_6_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2212950 bases in 506 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_6_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2585515 bases in 511 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_7_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3365897 bases in 671 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_7_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3320186 bases in 635 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_7_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2603361 bases in 515 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_7_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2809384 bases in 578 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_8_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3157290 bases in 676 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_8_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3109224 bases in 626 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_8_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2098546 bases in 492 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_8_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2615387 bases in 560 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_9_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3602164 bases in 711 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_9_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3626236 bases in 720 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_9_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2543427 bases in 537 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_9_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2326373 bases in 445 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_10_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 4118386 bases in 825 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_10_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3156775 bases in 582 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_10_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 1864007 bases in 354 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_10_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3145421 bases in 637 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_11_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2692732 bases in 555 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_11_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2987511 bases in 665 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_11_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2850202 bases in 588 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_11_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2657650 bases in 465 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_12_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2534187 bases in 492 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_12_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 4239933 bases in 924 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_12_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3864334 bases in 750 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_12_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2746376 bases in 551 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_13_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3971501 bases in 789 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_13_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2525267 bases in 498 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_13_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2349566 bases in 486 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_13_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2275940 bases in 450 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_14_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2971529 bases in 600 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_14_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2452722 bases in 479 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_14_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3068711 bases in 642 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_14_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2671844 bases in 527 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_15_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2803965 bases in 585 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_15_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3642778 bases in 667 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_15_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2970278 bases in 629 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_15_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 1897509 bases in 407 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_16_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 4486946 bases in 861 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_16_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3254833 bases in 634 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_16_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2247966 bases in 443 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_16_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 
3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 1984000 bases in 351 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_67_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3019789 bases in 657 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_67_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3875241 bases in 799 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_67_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2898736 bases in 540 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_67_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2559459 bases in 555 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_68_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2742768 bases in 549 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_68_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2320856 bases in 451 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_68_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2528545 bases in 494 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_68_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2274987 bases in 425 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_69_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 1464664 bases in 286 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_69_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 1491776 bases in 254 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_69_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2270309 bases in 403 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_69_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 921837 bases in 185 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_70_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 4059454 bases in 851 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_70_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2732957 bases in 551 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_70_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3277275 bases in 667 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_70_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2536700 bases in 526 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_71_0.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2413750 bases in 519 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_71_1.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3660438 bases in 790 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_71_2.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 3273850 bases in 676 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders
#
# fastq_runid_c027f2d22e85a0e84e8f139f20f7e02234fe550f_71_3.fastq
# Reading and filtering the reads
# Running BLAT to find splint locations (This can take hours)
# Loaded 624 letters in 26 sequences
# Searched 2714559 bases in 545 sequences
# Parsing BLAT output
# Writing fastq output files in bins of 4000 into separate folders

# %%
reads_per_guide = dict.fromkeys(range(1,27), 0)
for x in os.listdir(pre_dir):
    for guide in range(1,27):
        if "splint_g%02d" % guide in os.listdir(os.path.join(pre_dir, x)):
            splint_dir = os.path.join(pre_dir, x, "splint_g%02d" % guide)
            if os.listdir(splint_dir):
                fastq = open(os.path.join(splint_dir, "R2C2_raw_reads.fastq"), 'r')
                for line in fastq:
                    if line.strip() == "+":
                        reads_per_guide[guide] += 1

# %%
print("Total Reads After Preprocessing:", sum(reads_per_guide.values()))
print("% of Basecalled Reads:", 100. * sum(reads_per_guide.values()) / reads_basecalled)
# Out:
# Total Reads After Preprocessing: 155455
# % of Basecalled Reads: 95.19712427586376

# %% [markdown]
# # Processing
# Consolidate repeats in each concatemer into one consensus read using C3POa.

# %%
consensus_dir = os.path.join(output_dir, "consensus") # store consensus reads in this directory
temp_dir = os.path.join(consensus_dir, "temp")

# %%
raw_seq_length_cutoff = 100
peak_dist_cutoff = 100 # Median distance between peaks cutoff. This should be the length of your shortest input sequence in your library preparation.

# %%
for d in os.listdir(pre_dir):
    for guide in range(1,27):
        reads_file = os.path.join(pre_dir, d, "splint_g%02d" % guide, "R2C2_raw_reads.fastq")
        if os.path.isfile(reads_file):
            current_temp_dir = os.path.join(temp_dir, "temp_dir%s_g%02d" % (d, guide))
            if not os.path.exists(current_temp_dir):
                os.makedirs(current_temp_dir)
            out_file = os.path.join(consensus_dir, "R2C2_consensus_g%02d.fasta" % (guide))
            partial_reads_file = os.path.join(consensus_dir, "R2C2_partial_reads_g%02d.fasta" % (guide))
            process_cmd = "C3POa/C3POa.py -r %s -p %s -m %s -l %d -d %d -c %s -o %s -s %s" % (reads_file, current_temp_dir, nuc_mat, raw_seq_length_cutoff, peak_dist_cutoff, config, out_file, partial_reads_file)
            # !python3 {process_cmd}

# %%
copies_per_guide = dict.fromkeys(range(1,27))
for x in copies_per_guide:
    copies_per_guide[x] = []
for guide in range(1,27):
    fasta = open(os.path.join(consensus_dir, "R2C2_consensus_g%02d.fasta" % guide), 'r')
    for line in fasta:
        if line[0] == ">":
            copies_per_guide[guide].append(int(line.split("_")[3]) + 1)
    fasta.close()
    fasta = open(os.path.join(consensus_dir, "R2C2_partial_reads_g%02d.fasta" % guide), 'r')
    for line in fasta:
        if line[0] == ">":
            copies_per_guide[guide].append(1)
    fasta.close()

# %%
print("Total Reads After Processing:", sum([len(copies_per_guide[x]) for x in copies_per_guide]))
print("% of Basecalled Reads:", 100. * sum([len(copies_per_guide[x]) for x in copies_per_guide]) / reads_basecalled)
# Out:
# Total Reads After Processing: 149877
# % of Basecalled Reads: 91.78128329801957

# %% [markdown]
# # Analysis

# %%
normalization_dict = pk.load(open("normalization_dict.pkl", "rb"))

# %%
fig, ax = plt.subplots(figsize=(8,4))
for guide, x in copies_per_guide.items():
    if guide == 26:
        continue
    if guide in [2,13,24]:
        ax.bar(guide, float(len(x)) / sum([len(copies_per_guide[x]) for x in copies_per_guide]), color="#6EB3E4")
    else:
        ax.bar(guide, float(len(x)) / sum([len(copies_per_guide[x]) for x in copies_per_guide]), color="silver")
        
plt.xticks(list(copies_per_guide.keys())[:-1])
ax.set_yscale('log')
plt.xlabel("File #")
plt.ylabel("Fraction of Total Concatemers")
plt.title("%s - Concatemers Per File" % date)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))
for guide in range(1,26):
    if guide in [2,13,24]:
        ax.scatter([1], float(len(copies_per_guide[guide])) / sum([len(x) for x in copies_per_guide.values()]), color='purple', marker='x')
    else:
        ax.scatter([2], float(len(copies_per_guide[guide])) / sum([len(x) for x in copies_per_guide.values()]), color='purple', marker='x')
ax.set_xticks(range(1,3))
ax.set_xticklabels(['Accessed', 'Unaccessed'])
ax.set_yscale('log')
plt.xlim(0.5,2.5)
plt.ylabel("Fraction of Total Concatemers")
plt.title('%s - Fraction of Concatemers Read for Accessed vs. Unaccessed Files' % date)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
for guide, x in copies_per_guide.items():
    if guide == 26:
        continue
    if guide in [2,13,24]:
        plt.bar(guide, float(len(x)) / sum([len(copies_per_guide[x]) for x in copies_per_guide]) / normalization_dict[guide],
                color="#6EB3E4")
    else:
        plt.bar(guide, float(len(x)) / sum([len(copies_per_guide[x]) for x in copies_per_guide]) / normalization_dict[guide], 
                color="silver")
        
plt.xticks(list(copies_per_guide.keys())[:-1])
ax.set_yscale('log')
plt.xlabel("File #")
plt.ylabel("Enrichment Score")
plt.title("%s - Concatemers Per File (Enrichment Scores)" % date)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))
for guide in range(1,26):
    if guide in [2,13,24]:
        ax.scatter([1], float(len(copies_per_guide[guide])) / sum([len(x) for x in copies_per_guide.values()]) / normalization_dict[guide], color='purple', marker='x')
    else:
        ax.scatter([2], float(len(copies_per_guide[guide])) / sum([len(x) for x in copies_per_guide.values()]) / normalization_dict[guide], color='purple', marker='x')
ax.set_xticks(range(1,3))
ax.set_xticklabels(['Accessed', 'Unaccessed'])
ax.set_yscale('log')
plt.xlim(0.5,2.5)
plt.ylabel("Enrichment Score")
plt.title('%s - Enrichment Score for Accessed vs. Unaccessed Files' % date)
plt.show()

# %%
plt.figure(figsize=(8,4))
for guide, x in copies_per_guide.items():
    if guide == 26:
        continue
    if guide in [2,13,24]:
        plt.bar(guide, np.mean(x), color="#6EB3E4")
    else:
        plt.bar(guide, np.mean(x), color="silver")
plt.xticks(list(copies_per_guide.keys())[:-1])
plt.xlabel("File #")
plt.ylabel("Mean # of Copies per Concatemer")
plt.title("%s - Number of Copies Per Concatemer" % date)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))
for guide in range(1,26):
    if guide in [2,13,24]:
        ax.scatter([1], np.mean(copies_per_guide[guide]), color='purple', marker='x')
    else:
        ax.scatter([2], np.mean(copies_per_guide[guide]), color='purple', marker='x')
ax.set_xticks(range(1,3))
ax.set_xticklabels(['Accessed', 'Unaccessed'])
plt.xlim(0.5,2.5)
plt.ylabel("# of Copies per Concatemer")
plt.title('%s - Mean Concatemer Length for Accessed vs. Unaccessed Files' % date)
plt.show()
